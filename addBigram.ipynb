# %%
import pandas as pd
df = pd.read_csv("ContainsDatasetDrop529.csv")
bi_and_tri = pd.read_csv("commonBigrams.csv")

bi_and_tri
# Out:
#    Starting Letter Terminating Letter Common Bigrams Common Trigrams
# 0                t                  e             th             the
# 1                a                  s             he             and
# 2                i                  d             in             tha
# 3                s                  t             en             ent
# 4                o                  n             nt             ing
# 5                c                  y             re             ion
# 6                m                  r             er             tio
# 7                f                  o             an             for
# 8                p                  l             ti             nde
# 9                w                  f             es             has
# 10             NaN                NaN             on             nce
# 11             NaN                NaN             at             edt
# 12             NaN                NaN             se             tis
# ...

# %%
for i in range(28):
    curName = "commonBigram" + str(i)
    df[curName] =  [x.__contains__(bi_and_tri['Common Bigrams'][i]) for x in df['Word']]

# df["commonTrigram0"] = [x.__contains__(bi_and_tri['Common Trigrams'][0]) for x in df['Word']]
df['bigrams'] = [0] * 358
for j in range(28):
    currentName = "commonBigram" + str(j)
    df['bigrams'] += df[currentName]
df['bigrams'].sum()
# df['commonBigram'] = df['commonBigram0'] + df['commonBigram1'] + df['commonBigram2'] + df['commonBigram3'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] + df['commonBigram'] +
# Out:
# 315

# %%
for i in range(16):
    if (str(bi_and_tri['Common Trigrams'][i]) != "nan"):
        curName = "commonTrigram" + str(i)
        print(bi_and_tri['Common Trigrams'][i])
        # print([x for x in df['Word']])
        df[curName] =  [x.__contains__(bi_and_tri['Common Trigrams'][i]) for x in df['Word']]

# df["commonTrigram0"] = [x.__contains__(bi_and_tri['Common Trigrams'][0]) for x in df['Word']]
df['trigrams'] = [0] * 358
for j in range(16):
    currentName = "commonTrigram" + str(j)
    df['trigrams'] += df[currentName]
df['trigrams'].sum()
# Out:
# the
# and
# tha
# ent
# ing
# ion
# tio
# for
# nde
# has
# nce
# edt
# tis
# oft
# sth
# men
# 17

# %%
for j in range(16):
    currentName = 'commonTrigram' + str(j)
    df.drop(columns=[currentName])
df
# Out:
#      Unnamed: 0                 Date  ContestNumber   Word  ReportedResults  \
# 0             1  2022-12-31 00:00:00            560  manly            20380
# 1             2  2022-12-30 00:00:00            559  molar            21204
# 2             3  2022-12-29 00:00:00            558  havoc            20001
# 3             4  2022-12-28 00:00:00            557  impel            20160
# 4             5  2022-12-27 00:00:00            556  condo            20879
# ..          ...                  ...            ...    ...              ...
# 353         355  2022-01-11 00:00:00            206  drink           153880
# 354         356  2022-01-10 00:00:00            205  query           107134
# 355         357  2022-01-09 00:00:00            204  gorge            91477
# 356         358  2022-01-08 00:00:00            203  crank           101503
# 357         359  2022-01-07 00:00:00            202  slump            80630
#
# ...

# %%
df.to_csv("bigrams_and_trigrams.csv")
